# %% [markdown]
# # Tracing your code

# %% [markdown]
# ```{tip} This video explains how to trace (stepping through code, line by line). This is a **very** useful for debugging and an essential skill.
# ```

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("r3-ryfNoZv4")
